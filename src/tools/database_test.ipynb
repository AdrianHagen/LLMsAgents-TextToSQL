# %%
from database import Database

db1 = Database("european_football_2")
db2 = Database("european_football_2")

db3 = Database("european_football_2")
db4 = Database("european_football_2")

db1.get_connection()
db2.get_connection()
db3.get_connection()

# %%
import pandas as pd
dev = pd.read_json("../../data/dev/dev.json")

# %%
for query in dev.itertuples():
    db = Database(query.db_id)
    result, execution_time = db.execute_query(query.SQL)
    print(execution_time)
# Out:
# Query executed in 0.0014 seconds
# Query executed in 0.0013 seconds
# Query executed in 0.0019 seconds
# Query executed in 0.0107 seconds
# Query executed in 0.0137 seconds
# Query executed in 0.0138 seconds
# Query executed in 0.0027 seconds
# Query executed in 0.0008 seconds
# Query executed in 0.0014 seconds
# Query executed in 0.0011 seconds
# Query executed in 0.0010 seconds
# Query executed in 0.0053 seconds
# Query executed in 0.0011 seconds
# Query executed in 0.0043 seconds
# Query executed in 0.0062 seconds
# Query executed in 0.0047 seconds
# Query executed in 0.0031 seconds
# Query executed in 0.0030 seconds
# Query executed in 0.0012 seconds
# Query executed in 0.0043 seconds
# Query executed in 0.0025 seconds
# Query executed in 0.0012 seconds
# Query executed in 0.0002 seconds
# Query executed in 0.0069 seconds
# Query executed in 0.0014 seconds
# Query executed in 0.0012 seconds
# Query executed in 0.0025 seconds
# Query executed in 0.0124 seconds
# ...
